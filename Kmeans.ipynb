# %% [markdown]
# # The Sparks Foundation - Data Science & Business Analytics Internship

# %% [markdown]
# # Author - Ritika Kalra

# %% [markdown]
# # Prediction using Unsupervised ML

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets
import seaborn as sns
import sklearn

# %% [markdown]
# # Loading the dataset

# %%
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns = iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# # Exploring the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
corr = df.corr(method='pearson')
sns.heatmap(corr, annot=True)

# %% [markdown]
# # Elbow method

# %%
x = df.iloc[:, [0, 1, 2, 3]].values

from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
    
# Plotting the results onto a line graph, 
# `allowing us to observe 'The elbow'
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') # Within cluster sum of squares
plt.show()

# %% [markdown]
# ## optimal k=3

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++',
                max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %%
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], 
            s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], 
            s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],
            s = 100, c = 'green', label = 'Iris-virginica')

# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()

# %% [markdown]
# # Performance Measures

# %%
from sklearn.metrics import silhouette_score
coefficients_list= []
for k in range(2, 13):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter=301, n_init=10)
    kmeans.fit(x)
    s_score = silhouette_score(x,kmeans.labels_)
    coefficients_list.append(s_score)
coefficients_list
# Out:
# [0.3038726487385444,
#  0.3313978508178809,
#  0.3180581601075364,
#  0.32385301407651323,
#  0.3170567153162864,
#  0.3099468476965373,
#  0.3103556951752834,
#  0.31528816942634363,
#  0.2974930960420221,
#  0.3161795813856138,
#  0.33302318664053804]

# %%
plt.plot(range(2, 13), coefficients_list)
plt.title('Silhouette Graph')
plt.xlabel('Clusters')
plt.ylabel('Silhouette Coefficients ')
plt.show() #best silhouette score at n=3

# %%
sil_avg=silhouette_score(x,kmeans.labels_)
print("silhouette Score : ",sil_avg) #measure of distance between clusters
# Out:
# silhouette Score :  0.33302318664053804

# %%
db=sklearn.metrics.davies_bouldin_score(x,kmeans.labels_)
print("Davies_bouldin Score :",db) #measure of similarity
# Out:
# Davies_bouldin Score : 1.0016626980787433

# %% [markdown]
# # Heirarchial Clustering

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt
link = linkage(x, 'average') #consider average dist between clusters
figure = plt.figure(figsize=(7,5 ))
plt.title('Average linkage')
plt.xlabel('Target')
plt.ylabel('Euclidean distances')
dando = dendrogram(link)

link = linkage(x, 'single') #consider shortest dist between clusters
figure = plt.figure(figsize=(7, 5))
plt.title('Single Linkage')
plt.xlabel('Target')
plt.ylabel('Euclidean distances')
dando = dendrogram(link)

link = linkage(x, 'ward') #consider wcss dist between clusters
figure = plt.figure(figsize=(7, 5))
plt.title('Ward')
plt.xlabel('Target')
plt.ylabel('Euclidean distances')
dando = dendrogram(link)

link = linkage(x, 'complete') #consider farthest dist between clusters
figure = plt.figure(figsize=(7, 5))
plt.title('Complete')
dando = dendrogram(link)
plt.xlabel('Target')
plt.ylabel('Euclidean distances')
plt.show()
